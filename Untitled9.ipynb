# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x=np.arange(10)
x=x**2
print(x)
# Out:
# [ 0  1  4  9 16 25 36 49 64 81]

# %%
plt.plot(x)
#plt.show()
a=x*x
plt.show()
plt.scatter(x,a,marker="*",label="DD")
plt.legend()
plt.xlabel("Days")
plt.title("Routine")
plt.ylabel("Working hours")
# Out:
# Text(0, 0.5, 'Working hours')

# %% [markdown]
# ## num=np.random.randint(0,5,5)
# n=np.arange(5)
# print(num)
# print(n)

# %%
plt.bar(n,num,0.5,label="Caffiene Daily",color="Silver")
plt.bar(n+0.5,num*2,0.5,label="Fruits",color="Orange")
plt.legend()
plt.show()

# %%
label=['dd','ee','ff','gg']
values=[20,30,40,50]
plt.pie(values,labels=label,radius=1,shadow=True,explode=(0,1,0,0),colors=["green","black","pink","blue"])
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

#data x as acidity y density of milk

# %%
def readData(filename)
    df=pd.read_csv(filename)         #it reads files
    return df.values                #it converts into an array
x=readData()
x=x.reshape(99,)
y=y.reshape(99,)
print(x)
print(y)
plt.

# %%
def hypothesis(theta,x):
        return theta[0]+theta[1]*x

def error(X,Y,theta):
    total_error=0
    m=X.shape[0]
    
    for i in range(m):
        total_error+=(Y[i]- hypothesis(theta,X[i]))**2
        
    return 0.5*total_error
def gradientDecent(X,Y,learning_rate,maxItr)
